# %%
import pandas as pd

# %%
df = pd.read_csv('Files/jd_24.csv.csv')
df.head()
# Out:
#                                        product_image  keywords  \
# 0  https://i8.amplience.net/i/jpl/jd_FM0805_a?qlt=92       NaN
# 1  https://i8.amplience.net/i/jpl/jd_EF7885_a?qlt=92       NaN
# 2  https://i8.amplience.net/i/jpl/jd_EF4814_a?qlt=92       NaN
# 3  https://i8.amplience.net/i/jpl/jd_138887_a?qlt=92       NaN
# 4  https://i8.amplience.net/i/jpl/jd_DT5269_a?qlt=92       NaN
#
#         download_time                                                url  \
# 0  3/21/2020 01:03:29  https://www.jdsports.co.uk/product/black-adida...
# 1  3/21/2020 01:03:37  https://www.jdsports.co.uk/product/reebok-club...
# 2  3/21/2020 01:03:47  https://www.jdsports.co.uk/product/adidas-perf...
# 3  3/21/2020 01:03:00  https://www.jdsports.co.uk/product/blue-adidas...
# 4  3/21/2020 01:03:06  https://www.jdsports.co.uk/product/adidas-perf...
#
#   category                            sub_category  \
# 0      Men          Mens Clothing > Football Shirt
# ...

# %%
df.count()
# Out:
# product_image               37536
# keywords                        0
# download_time               41979
# url                         41979
# category                    37536
#                             ...
# coupon_on_full_page_text        0
# alcohol_content                 0
# mpc                             0
# secondary_image_total       37537
# shipping_dimensions             0
# Length: 108, dtype: int64

# %%
df1 = df.drop_duplicates()
df1.count()
# Out:
# product_image               37530
# keywords                        0
# download_time               41973
# url                         41973
# category                    37530
#                             ...
# coupon_on_full_page_text        0
# alcohol_content                 0
# mpc                             0
# secondary_image_total       37531
# shipping_dimensions             0
# Length: 108, dtype: int64
