# %%
import pandas as pd
df1 = pd.read_excel('Files/way_fair.xlsx')

# %%
df1.columns
# Out:
# Index(['product_name', 'product_url', 'pid', 'alias', 'brand',
#        'category_title', 'sku', 'attributes', 'price', 'special_price',
#        'product_weight', 'description', 'weights_dimensions', 'specifications',
#        'delivery_text', 'delivery_date', 'rating', 'total_reviews', 'images',
#        'instock', 'crawl_date'],
#       dtype='object')

# %%
df1['category_title'] = df1['category_title'].str.replace('/>' ,',')

# %%
df1.head()
# Out:
#                                         product_name  \
# 0                        Thoms Upholstered Bed Frame
# 1                                 Plymouth Bed Frame
# 2  Berlin Upholstered Ottoman Bed\nBerlin Upholst...
# 3             Hamby Platform Bed\nHamby Platform Bed
# 4  Bjorn Upholstered Divan Base\nBjorn Upholstere...
#
#                                          product_url                    pid  \
# 0  https://www.wayfair.co.uk/furniture/pdp/wrough...  1913001312_1913001339
# 1  https://www.wayfair.co.uk/furniture/pdp/home-h...               15864364
# 2  https://www.wayfair.co.uk/furniture/pdp/home-h...      26730935_26824197
# 3  https://www.wayfair.co.uk/furniture/pdp/wrough...               20407052
# 4  https://www.wayfair.co.uk/furniture/pdp/rosdor...               35944634
#
#                                                alias           brand  \
# 0  wrought-studio-thoms-upholstered-bed-frame-u00...  Wrought Studio
# ...

# %%
df1.to_excel('Files/wayfair_fix.xlsx', index=False)
