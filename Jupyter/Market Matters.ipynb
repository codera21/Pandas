# %%
import pandas as pd 
df = pd.read_excel('Files/mm.xlsx')
df.head()
# Out:
#                                                Title             Date  \
# 0  Bond yields firm, oil surges should we “run” f...  17 September 19
# 1  Subscribers questions (BHP, OZL, IIND, MSB, MG...  16 September 19
# 2  Does the Healthcare sector look poised to repe...  13 September 19
# 3  Could Iran & Aramco become too much for the Oi...  12 September 19
# 4  Overseas Wednesday – International Equities & ...  11 September 19
#
#            Author                                            Content  \
# 0  Market Matters  [ IMAGE: https://www.marketmatters.com.au/reso...
# 1  Market Matters  [ IMAGE: https://www.marketmatters.com.au/reso...
# 2  Market Matters  [ IMAGE: https://www.marketmatters.com.au/reso...
# 3  Market Matters  [ IMAGE: https://www.marketmatters.com.au/reso...
# 4  Market Matters  [ IMAGE: https://www.marketmatters.com.au/reso...
#
#                                               Images  Charts        Category  \
# ...
