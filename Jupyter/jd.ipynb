# %%
import pandas as pd

# %%
df = pd.read_csv('Files/jd_24.csv')
df.head()
# Out:
#                                        product_image  keywords  \
# 0  https://i8.amplience.net/i/jpl/jd_FM0805_a?qlt=92       NaN
# 1  https://i8.amplience.net/i/jpl/jd_EF7885_a?qlt=92       NaN
# 2  https://i8.amplience.net/i/jpl/jd_CW5565_a?qlt=92       NaN
# 3                                                NaN       NaN
# 4  https://i8.amplience.net/i/jpl/jd_FP9089_a?qlt=92       NaN
#
#         download_time                                                url  \
# 0  3/24/2020 01:03:29  https://www.jdsports.co.uk/product/black-adida...
# 1  3/24/2020 01:03:43  https://www.jdsports.co.uk/product/reebok-club...
# 2  3/24/2020 01:03:52  https://www.jdsports.co.uk/product/adidas-perf...
# 3  3/24/2020 01:03:09  https://www.jdsports.co.uk/product/adidas-perf...
# 4  3/24/2020 01:03:06  https://www.jdsports.co.uk/product/reebok-work...
#
#   category                          sub_category  \
# 0      Men        Mens Clothing > Football Shirt
# ...

# %%
df.count()
# Out:
# product_image               37541
# keywords                        0
# download_time               41992
# url                         41992
# category                    37541
#                             ...
# coupon_on_full_page_text        0
# alcohol_content                 0
# mpc                             0
# secondary_image_total       37542
# shipping_dimensions             0
# Length: 108, dtype: int64

# %%
df1 = df.drop_duplicates()
df1.count()
# Out:
# product_image               37541
# keywords                        0
# download_time               41992
# url                         41992
# category                    37541
#                             ...
# coupon_on_full_page_text        0
# alcohol_content                 0
# mpc                             0
# secondary_image_total       37542
# shipping_dimensions             0
# Length: 108, dtype: int64
